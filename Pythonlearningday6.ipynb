# %%
data="sarts"
start=0
end=4
data[start]

data[end]
# Out:
# 's'

# %%
data="sarts"
start=0
end=4
data[start]==data[end]
# Out:
# True

# %%
data="sarts"
start=0
end=4
data[start]!=data[end]
# Out:
# False

# %%
data="sarts"
start=0
end=4
cond=0
while(start<=end):
    if(data[start]!=data[end]):
        cond=1
        break
    start+=1
    end-=1
if(cond==0):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# not palindrome

# %%
data="naman"
start=0
end=4
cond=0
while(start<=end):
    if(data[start]!=data[end]):
        cond=1
        break
    start+=1
    end-=1
if(cond==0):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
# while loop using(palindrome)
s="naman"
num=0
last=len(s)-1
while(num< last ):
    if(s[num]!=s[last] ):
        print("not palindrome")
        break
    num+=1
    last-=1
else:
    print("palindrome")
# Out:
# palindrome

# %%
data="naman"
a=0
last=len(s)-1
mid=len(s)//2
for i in range(0,mid):
  print(i, s[i], s[end])
# Out:
# 0 n a
# 1 a a

# %%
# for loop using(palindrome)
data="naman"
last=len(s)-1
mid=len(s)//2
cond=True
for i in range(0,mid):
  if(s[i]!=s[last]):
    cond=False
    break
  last=last-1

if(cond==True):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
# armstrong number
n=153
y1=n%10
n=n//10
print(n,y1,y1**3)
y2=n%10
n=n//10
print(n,y2)
y3=n%10
n=n//10
print(n,y3)
# Out:
# 15 3 27
# 1 5
# 0 1

# %%
num=153
temp=num
total=0
while(num>0):
    rem=num%10
    total=total+rem**3
    num=num//10
if(num==temp):
        print("armstrong")
else:
    print("not armstrong")
# Out:
# not armstrong

# %%
n=153
x=n
y=0
total=0
while(n>0):
  y=n%10
  total=total+y**3
  n=n//10
if(n==total):
  print("armstrong")
else:
  print("not armstrong")
# Out:
# not armstrong

# %%
n=153
x=n
y=0
total=0
while(n>0):
  y=n%10
  total=total+y**3
  n=n//10
  print("n=>",n,"y=>",y,"total=>",total)
if(n==total):
  print("armstrong")
else:
  print("not armstrong")
# Out:
# n=> 15 y=> 3 total=> 27
# n=> 1 y=> 5 total=> 152
# n=> 0 y=> 1 total=> 153
# not armstrong
